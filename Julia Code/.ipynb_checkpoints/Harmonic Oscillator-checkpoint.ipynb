# %%
include("DG_Functions.jl")
include("Specific_DG_Functions.jl")
include("DG_Methods.jl")
include("Differentiation.jl")
include("DG_Derivative.jl")
include("DG_Derivative_Matrix.jl")
# Out:
# WARNING: redefining constant Leg_coeffs
# WARNING: redefining constant DG_coeffs
# WARNING: redefining constant Leg_coeffs
# WARNING: redefining constant DG_coeffs
# WARNING: redefining constant Leg_coeffs
# WARNING: redefining constant DG_coeffs
# WARNING: redefining constant Leg_coeffs
# WARNING: redefining constant DG_coeffs
# WARNING: redefining constant Leg_coeffs
# WARNING: redefining constant DG_coeffs
# WARNING: redefining constant Leg_coeffs
# WARNING: redefining constant DG_coeffs
# WARNING: redefining constant Leg_coeffs
# WARNING: redefining constant DG_coeffs
# WARNING: redefining constant Leg_coeffs
# WARNING: redefining constant DG_coeffs

# %%
function time_evolve(coeffs::Dict{CartesianIndex{D}, Array{Array{Float64},D}},
    coeffs_dot::Dict{CartesianIndex{D}, Array{Array{Float64},D}},dt::Real)
    
    for key in keys(coeffs)
        ks = ntuple(i -> 1<<pos(key[i]-2), D) 
        for place in CartesianRange(ks)
            for f_number in CartesianRange(f_numbers)
                coeffs[key][place][f_number] += coeffs_dot[key][place][f_number]*dt
            end
        end
    end
end

# %%
func = (x-> sin(pi*x[1]))
coeffs=hier_coefficients_DG(5,func,(6,))
dcoeffs=diff_coefficients_DG(1,5,coeffs)
ddcoeffs = diff_coefficients_DG(1,5,dcoeffs)
# Out:
# Dict{CartesianIndex{1},Array{Array{Float64,N},1}} with 6 entries:
#   CartesianIndex{1}((3,)) => Array{Float64,N}[[-0.00025150487648827903,2.432928…
#   CartesianIndex{1}((5,)) => Array{Float64,N}[[1.1768104941464252e-6,8.95839442…
#   CartesianIndex{1}((2,)) => Array{Float64,N}[[7.321724626587907e-11,0.00286228…
#   CartesianIndex{1}((6,)) => Array{Float64,N}[[2.0718181153673327e-6,3.27462180…
#   CartesianIndex{1}((1,)) => Array{Float64,N}[[-6.283185233563579,1.30743549740…
#   CartesianIndex{1}((4,)) => Array{Float64,N}[[-6.385844960574888e-6,4.08891712…

# %%
plotfunc1D(x-> reconstruct_DG(5,coeffs,[x[1]])-sin(pi*x[1]))
plotfunc1D(x-> reconstruct_DG(5,ddcoeffs,[x[1]])+pi^2*sin(pi*x[1]))
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x31e24d2d0>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x31eff6350>
