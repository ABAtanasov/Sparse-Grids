# %%
using PyPlot
using Cubature 


include("DG_Functions.jl")
include("Specific_DG_Functions.jl")
include("DG_Methods.jl")
# Out:
# //anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# WARNING: redefining constant Leg_coeffs
# WARNING: redefining constant DG_coeffs
# reconstruct_DG (generic function with 1 method)

# %%
plotfunc1D(x->array2poly([0,0,0,1],2x[1]-1))
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x323510d10>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x32366cb90>
